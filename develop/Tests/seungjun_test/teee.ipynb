# %%
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

img = Image.open('c:\\Users\\IT\\Desktop\\test\\kantata.jpg')
new_image = np.array(img)
new = Image.fromarray(np.uint8(new_image))
print(img)
print(new)
w, h = new.size
print(w)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x550 at 0x27020880A88>
# <PIL.Image.Image image mode=RGB size=550x550 at 0x27020801748>
# 550
